# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Data Preprocessing

# %%
dataset = pd.read_csv('4.2 Churn_Modelling.csv')
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
x = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
print(x)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_x_2 = LabelEncoder()
x[:, 2] = labelencoder_x_2.fit_transform(x[:, 2])
print(x)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %%
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('ohe', OneHotEncoder(), [1])], remainder='passthrough')
x = np.array(ct.fit_transform(x), dtype = str) #.toarray()
x = x[:, 1:]
print(x)
# Out:
# [['0.0' '0.0' '619' ... '1' '1' '101348.88']
#  ['0.0' '1.0' '608' ... '0' '1' '112542.58']
#  ['0.0' '0.0' '502' ... '1' '0' '113931.57']
#  ...
#  ['0.0' '0.0' '709' ... '0' '1' '42085.58']
#  ['1.0' '0.0' '772' ... '1' '0' '92888.52']
#  ['0.0' '0.0' '792' ... '1' '0' '38190.78']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-0.5698444 ,  1.74309049,  0.16958176, ...,  0.64259497,
#         -1.03227043,  1.10643166],
#        [ 1.75486502, -0.57369368, -2.30455945, ...,  0.64259497,
#          0.9687384 , -0.74866447],
#        [-0.5698444 , -0.57369368, -1.19119591, ...,  0.64259497,
#         -1.03227043,  1.48533467],
#        ...,
#        [-0.5698444 , -0.57369368,  0.9015152 , ...,  0.64259497,
#         -1.03227043,  1.41231994],
#        [-0.5698444 ,  1.74309049, -0.62420521, ...,  0.64259497,
#          0.9687384 ,  0.84432121],
#        [ 1.75486502, -0.57369368, -0.28401079, ...,  0.64259497,
#         -1.03227043,  0.32472465]])

# %% [markdown]
# # Creation du Model

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input

import tensorflow as tf
import random

# Fixer les seeds
## np.random.seed(42)
## tf.random.set_seed(42)
## random.seed(42)

# Nettoyer les sessions précédentes (important dans Jupyter)
tf.keras.backend.clear_session()

classifier = Sequential()

# %% [markdown]
# # Il y a desequilibre entre le valeur de sortie donc on calcul le poids automatiquement

# %%
from sklearn.utils import class_weight

# Calcul automatique des poids par classe parce que les class sont desequilibré
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Création du modèle
classifier.add(Input(shape=(11,)))  # input layer propre
classifier.add(Dense(units=32, kernel_initializer='uniform', activation='relu'))
classifier.add(Dense(units=16, kernel_initializer='uniform', activation='relu'))
classifier.add(Dense(units=8, kernel_initializer='uniform', activation='relu'))
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# %% [markdown]
# ### on a creer un modele avec 3 couche cahcé maintenant il faut le compilé

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Sauvegarde du meilleur modèle
checkpoint = ModelCheckpoint('Save/temp_modele.jupiter.keras', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
# Entraînement
history = classifier.fit(x_train, y_train, batch_size=10, epochs=100, validation_split=0.2, callbacks=[checkpoint], class_weight = class_weight_dict)
# Out:
# Epoch 1/100
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2589 - loss: 0.7024
# Epoch 1: val_accuracy improved from -inf to 0.79688, saving model to Save/temp_modele.jupiter.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.2590 - loss: 0.7024 - val_accuracy: 0.7969 - val_loss: 0.6918
# Epoch 2/100
# 637/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6732 - loss: 0.6916
# Epoch 2: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6734 - loss: 0.6916 - val_accuracy: 0.2031 - val_loss: 0.6935
# Epoch 3/100
# 633/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2344 - loss: 0.6961
# Epoch 3: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2343 - loss: 0.6961 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 4/100
# 624/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3739 - loss: 0.6972
# Epoch 4: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3744 - loss: 0.6971 - val_accuracy: 0.7969 - val_loss: 0.6926
# Epoch 5/100
# 636/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7846 - loss: 0.6832
# Epoch 5: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7836 - loss: 0.6833 - val_accuracy: 0.2031 - val_loss: 0.6940
# Epoch 6/100
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5089 - loss: 0.6911
# Epoch 6: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5094 - loss: 0.6911 - val_accuracy: 0.2031 - val_loss: 0.6954
# Epoch 7/100
# 611/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2110 - loss: 0.7008
# Epoch 7: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2114 - loss: 0.7006 - val_accuracy: 0.2031 - val_loss: 0.6945
# Epoch 8/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3753 - loss: 0.6968
# Epoch 8: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3755 - loss: 0.6968 - val_accuracy: 0.7969 - val_loss: 0.6924
# Epoch 9/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3365 - loss: 0.7027
# Epoch 9: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3408 - loss: 0.7024 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 10/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4459 - loss: 0.6926
# Epoch 10: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4478 - loss: 0.6926 - val_accuracy: 0.2031 - val_loss: 0.6943
# Epoch 11/100
# 619/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5021 - loss: 0.6848
# Epoch 11: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4998 - loss: 0.6851 - val_accuracy: 0.2031 - val_loss: 0.6948
# Epoch 12/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4812 - loss: 0.6846
# Epoch 12: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4845 - loss: 0.6848 - val_accuracy: 0.2031 - val_loss: 0.6963
# Epoch 13/100
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2889 - loss: 0.6949
# Epoch 13: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2891 - loss: 0.6948 - val_accuracy: 0.2031 - val_loss: 0.6955
# Epoch 14/100
# 619/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4292 - loss: 0.6847
# Epoch 14: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4318 - loss: 0.6851 - val_accuracy: 0.2031 - val_loss: 0.6968
# Epoch 15/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2124 - loss: 0.7036
# Epoch 15: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2122 - loss: 0.7034 - val_accuracy: 0.7969 - val_loss: 0.6929
# Epoch 16/100
# 618/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6139 - loss: 0.6937
# Epoch 16: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6090 - loss: 0.6937 - val_accuracy: 0.7969 - val_loss: 0.6929
# Epoch 17/100
# 620/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5543 - loss: 0.6933
# Epoch 17: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5496 - loss: 0.6933 - val_accuracy: 0.2031 - val_loss: 0.6932
# Epoch 18/100
# 621/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7109 - loss: 0.6928
# Epoch 18: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7088 - loss: 0.6928 - val_accuracy: 0.2031 - val_loss: 0.6935
# Epoch 19/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2099 - loss: 0.7000
# Epoch 19: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2106 - loss: 0.6999 - val_accuracy: 0.7969 - val_loss: 0.6917
# Epoch 20/100
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7767 - loss: 0.6891
# Epoch 20: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7767 - loss: 0.6891 - val_accuracy: 0.2031 - val_loss: 0.6948
# Epoch 21/100
# 639/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2048 - loss: 0.6942
# Epoch 21: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2048 - loss: 0.6942 - val_accuracy: 0.2031 - val_loss: 0.6933
# Epoch 22/100
# 612/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3974 - loss: 0.6975
# Epoch 22: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3945 - loss: 0.6974 - val_accuracy: 0.7969 - val_loss: 0.6924
# Epoch 23/100
# 615/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6227 - loss: 0.6874
# Epoch 23: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6177 - loss: 0.6877 - val_accuracy: 0.7969 - val_loss: 0.6916
# Epoch 24/100
# 635/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3590 - loss: 0.7015
# Epoch 24: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3592 - loss: 0.7014 - val_accuracy: 0.7969 - val_loss: 0.6902
# Epoch 25/100
# 622/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6037 - loss: 0.6987
# Epoch 25: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6034 - loss: 0.6985 - val_accuracy: 0.7969 - val_loss: 0.6928
# Epoch 26/100
# 629/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.6850
# Epoch 26: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7997 - loss: 0.6852 - val_accuracy: 0.2031 - val_loss: 0.6941
# Epoch 27/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4209 - loss: 0.6919
# Epoch 27: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4203 - loss: 0.6919 - val_accuracy: 0.2031 - val_loss: 0.6944
# Epoch 28/100
# 629/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4525 - loss: 0.6917
# Epoch 28: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4552 - loss: 0.6917 - val_accuracy: 0.2031 - val_loss: 0.6949
# Epoch 29/100
# 624/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3281 - loss: 0.6940
# Epoch 29: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3278 - loss: 0.6940 - val_accuracy: 0.2031 - val_loss: 0.6942
# Epoch 30/100
# 633/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6017 - loss: 0.6872
# Epoch 30: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6016 - loss: 0.6873 - val_accuracy: 0.2031 - val_loss: 0.6955
# Epoch 31/100
# 627/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4441 - loss: 0.6879
# Epoch 31: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4448 - loss: 0.6880 - val_accuracy: 0.2031 - val_loss: 0.6951
# Epoch 32/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4896 - loss: 0.6856
# Epoch 32: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4904 - loss: 0.6858 - val_accuracy: 0.2031 - val_loss: 0.6963
# Epoch 33/100
# 629/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2208 - loss: 0.7110
# Epoch 33: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2216 - loss: 0.7107 - val_accuracy: 0.7969 - val_loss: 0.6919
# Epoch 34/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6067 - loss: 0.6915
# Epoch 34: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6069 - loss: 0.6915 - val_accuracy: 0.7969 - val_loss: 0.6930
# Epoch 35/100
# 636/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3112 - loss: 0.7013
# Epoch 35: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3119 - loss: 0.7013 - val_accuracy: 0.2031 - val_loss: 0.6943
# Epoch 36/100
# 620/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4248 - loss: 0.6962
# Epoch 36: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4316 - loss: 0.6960 - val_accuracy: 0.7969 - val_loss: 0.6925
# Epoch 37/100
# 627/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6909 - loss: 0.6824
# Epoch 37: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6892 - loss: 0.6826 - val_accuracy: 0.2031 - val_loss: 0.6951
# Epoch 38/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2962 - loss: 0.6923
# Epoch 38: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2962 - loss: 0.6923 - val_accuracy: 0.2031 - val_loss: 0.6947
# Epoch 39/100
# 630/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2502 - loss: 0.6949
# Epoch 39: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2507 - loss: 0.6948 - val_accuracy: 0.7969 - val_loss: 0.6922
# Epoch 40/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3666 - loss: 0.6969
# Epoch 40: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3682 - loss: 0.6968 - val_accuracy: 0.7969 - val_loss: 0.6930
# Epoch 41/100
# 633/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3675 - loss: 0.6954
# Epoch 41: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3674 - loss: 0.6954 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 42/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7592 - loss: 0.6879
# Epoch 42: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7592 - loss: 0.6880 - val_accuracy: 0.2031 - val_loss: 0.6943
# Epoch 43/100
# 611/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2228 - loss: 0.7107
# Epoch 43: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2244 - loss: 0.7099 - val_accuracy: 0.7969 - val_loss: 0.6927
# Epoch 44/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6707 - loss: 0.6916
# Epoch 44: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6706 - loss: 0.6916 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 45/100
# 634/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4770 - loss: 0.6945
# Epoch 45: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4785 - loss: 0.6945 - val_accuracy: 0.2031 - val_loss: 0.6933
# Epoch 46/100
# 627/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4133 - loss: 0.6967
# Epoch 46: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4136 - loss: 0.6966 - val_accuracy: 0.2031 - val_loss: 0.6939
# Epoch 47/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5620 - loss: 0.6860
# Epoch 47: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5648 - loss: 0.6862 - val_accuracy: 0.2031 - val_loss: 0.6959
# Epoch 48/100
# 614/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2228 - loss: 0.6878
# Epoch 48: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2243 - loss: 0.6880 - val_accuracy: 0.2031 - val_loss: 0.6948
# Epoch 49/100
# 615/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4186 - loss: 0.6962
# Epoch 49: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4233 - loss: 0.6961 - val_accuracy: 0.2031 - val_loss: 0.6949
# Epoch 50/100
# 617/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2244 - loss: 0.6984
# Epoch 50: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2268 - loss: 0.6982 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 51/100
# 627/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6955 - loss: 0.6879
# Epoch 51: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6934 - loss: 0.6880 - val_accuracy: 0.2031 - val_loss: 0.6939
# Epoch 52/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2127 - loss: 0.7041
# Epoch 52: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2128 - loss: 0.7039 - val_accuracy: 0.7969 - val_loss: 0.6918
# Epoch 53/100
# 618/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7563 - loss: 0.6920
# Epoch 53: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7517 - loss: 0.6920 - val_accuracy: 0.7969 - val_loss: 0.6920
# Epoch 54/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6653 - loss: 0.6886
# Epoch 54: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6651 - loss: 0.6886 - val_accuracy: 0.2031 - val_loss: 0.6933
# Epoch 55/100
# 637/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5333 - loss: 0.6910
# Epoch 55: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5339 - loss: 0.6911 - val_accuracy: 0.2031 - val_loss: 0.6949
# Epoch 56/100
# 621/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2455 - loss: 0.6969
# Epoch 56: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2475 - loss: 0.6968 - val_accuracy: 0.7969 - val_loss: 0.6917
# Epoch 57/100
# 635/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3132 - loss: 0.7021
# Epoch 57: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3137 - loss: 0.7020 - val_accuracy: 0.7969 - val_loss: 0.6919
# Epoch 58/100
# 617/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4918 - loss: 0.7005
# Epoch 58: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4943 - loss: 0.7002 - val_accuracy: 0.7969 - val_loss: 0.6902
# Epoch 59/100
# 633/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5140 - loss: 0.6979
# Epoch 59: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5124 - loss: 0.6979 - val_accuracy: 0.7969 - val_loss: 0.6927
# Epoch 60/100
# 627/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7230 - loss: 0.6975
# Epoch 60: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7216 - loss: 0.6974 - val_accuracy: 0.7969 - val_loss: 0.6924
# Epoch 61/100
# 632/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5460 - loss: 0.6986
# Epoch 61: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5448 - loss: 0.6985 - val_accuracy: 0.7969 - val_loss: 0.6917
# Epoch 62/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7702 - loss: 0.6876
# Epoch 62: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7694 - loss: 0.6877 - val_accuracy: 0.7969 - val_loss: 0.6926
# Epoch 63/100
# 634/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4217 - loss: 0.6963
# Epoch 63: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4221 - loss: 0.6963 - val_accuracy: 0.2031 - val_loss: 0.6935
# Epoch 64/100
# 637/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2536 - loss: 0.6982
# Epoch 64: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2541 - loss: 0.6982 - val_accuracy: 0.2031 - val_loss: 0.6934
# Epoch 65/100
# 637/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2719 - loss: 0.7027
# Epoch 65: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2724 - loss: 0.7027 - val_accuracy: 0.7969 - val_loss: 0.6917
# Epoch 66/100
# 619/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.6919
# Epoch 66: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7328 - loss: 0.6919 - val_accuracy: 0.7969 - val_loss: 0.6929
# Epoch 67/100
# 635/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3040 - loss: 0.7022
# Epoch 67: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3039 - loss: 0.7021 - val_accuracy: 0.7969 - val_loss: 0.6921
# Epoch 68/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7813 - loss: 0.6880
# Epoch 68: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7807 - loss: 0.6880 - val_accuracy: 0.2031 - val_loss: 0.6932
# Epoch 69/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5281 - loss: 0.6919
# Epoch 69: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5294 - loss: 0.6919 - val_accuracy: 0.2031 - val_loss: 0.6942
# Epoch 70/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2197 - loss: 0.6940
# Epoch 70: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2201 - loss: 0.6940 - val_accuracy: 0.2031 - val_loss: 0.6935
# Epoch 71/100
# 622/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3129 - loss: 0.6968
# Epoch 71: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3129 - loss: 0.6967 - val_accuracy: 0.2031 - val_loss: 0.6936
# Epoch 72/100
# 623/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4825 - loss: 0.6926
# Epoch 72: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4785 - loss: 0.6926 - val_accuracy: 0.7969 - val_loss: 0.6930
# Epoch 73/100
# 623/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6442 - loss: 0.6930
# Epoch 73: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6433 - loss: 0.6930 - val_accuracy: 0.2031 - val_loss: 0.6935
# Epoch 74/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6092 - loss: 0.6870
# Epoch 74: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6089 - loss: 0.6870 - val_accuracy: 0.7969 - val_loss: 0.6926
# Epoch 75/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8002 - loss: 0.6834
# Epoch 75: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7991 - loss: 0.6836 - val_accuracy: 0.2031 - val_loss: 0.6953
# Epoch 76/100
# 634/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3036 - loss: 0.6960
# Epoch 76: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3041 - loss: 0.6960 - val_accuracy: 0.2031 - val_loss: 0.6954
# Epoch 77/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2990 - loss: 0.6921
# Epoch 77: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2994 - loss: 0.6921 - val_accuracy: 0.2031 - val_loss: 0.6937
# Epoch 78/100
# 632/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5988 - loss: 0.6885
# Epoch 78: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5984 - loss: 0.6886 - val_accuracy: 0.2031 - val_loss: 0.6957
# Epoch 79/100
# 635/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5787 - loss: 0.6841
# Epoch 79: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5783 - loss: 0.6842 - val_accuracy: 0.2031 - val_loss: 0.6950
# Epoch 80/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4511 - loss: 0.6856
# Epoch 80: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4516 - loss: 0.6857 - val_accuracy: 0.2031 - val_loss: 0.6938
# Epoch 81/100
# 636/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2770 - loss: 0.6956
# Epoch 81: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2778 - loss: 0.6955 - val_accuracy: 0.2031 - val_loss: 0.6949
# Epoch 82/100
# 620/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4681 - loss: 0.6868
# Epoch 82: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4673 - loss: 0.6871 - val_accuracy: 0.2031 - val_loss: 0.6943
# Epoch 83/100
# 624/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3728 - loss: 0.6880
# Epoch 83: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3721 - loss: 0.6882 - val_accuracy: 0.2031 - val_loss: 0.6956
# Epoch 84/100
# 626/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2533 - loss: 0.6989
# Epoch 84: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2563 - loss: 0.6987 - val_accuracy: 0.2031 - val_loss: 0.6933
# Epoch 85/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2184 - loss: 0.7024
# Epoch 85: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2187 - loss: 0.7022 - val_accuracy: 0.7969 - val_loss: 0.6923
# Epoch 86/100
# 629/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6655 - loss: 0.6914
# Epoch 86: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6665 - loss: 0.6914 - val_accuracy: 0.2031 - val_loss: 0.6934
# Epoch 87/100
# 633/640 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5064 - loss: 0.6894
# Epoch 87: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5070 - loss: 0.6895 - val_accuracy: 0.2031 - val_loss: 0.6958
# Epoch 88/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2600 - loss: 0.6926
# Epoch 88: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2603 - loss: 0.6926 - val_accuracy: 0.2031 - val_loss: 0.6953
# Epoch 89/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2086 - loss: 0.6989
# Epoch 89: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2087 - loss: 0.6989 - val_accuracy: 0.7969 - val_loss: 0.6928
# Epoch 90/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7673 - loss: 0.6811
# Epoch 90: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7649 - loss: 0.6813 - val_accuracy: 0.2031 - val_loss: 0.6947
# Epoch 91/100
# 632/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6857
# Epoch 91: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5103 - loss: 0.6858 - val_accuracy: 0.2031 - val_loss: 0.6934
# Epoch 92/100
# 631/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2278 - loss: 0.6983
# Epoch 92: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2286 - loss: 0.6982 - val_accuracy: 0.7969 - val_loss: 0.6929
# Epoch 93/100
# 630/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4340 - loss: 0.6965
# Epoch 93: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4320 - loss: 0.6964 - val_accuracy: 0.7969 - val_loss: 0.6926
# Epoch 94/100
# 617/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5814 - loss: 0.6942
# Epoch 94: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5847 - loss: 0.6942 - val_accuracy: 0.7969 - val_loss: 0.6931
# Epoch 95/100
# 625/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4333 - loss: 0.6948
# Epoch 95: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4336 - loss: 0.6948 - val_accuracy: 0.7969 - val_loss: 0.6923
# Epoch 96/100
# 636/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6435 - loss: 0.6875
# Epoch 96: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6439 - loss: 0.6875 - val_accuracy: 0.2031 - val_loss: 0.6964
# Epoch 97/100
# 628/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2730 - loss: 0.6961
# Epoch 97: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2749 - loss: 0.6960 - val_accuracy: 0.2031 - val_loss: 0.6952
# Epoch 98/100
# 636/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4077 - loss: 0.6921
# Epoch 98: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4083 - loss: 0.6921 - val_accuracy: 0.2031 - val_loss: 0.6947
# Epoch 99/100
# 632/640 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2830 - loss: 0.6922
# Epoch 99: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2854 - loss: 0.6922 - val_accuracy: 0.2031 - val_loss: 0.6944
# Epoch 100/100
# 638/640 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4504 - loss: 0.6901
# Epoch 100: val_accuracy did not improve from 0.79688
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4501 - loss: 0.6901 - val_accuracy: 0.2031 - val_loss: 0.6947

# %% [markdown]
# # Chargement du nouveau modèle seulement si elle est meilleur que l'ancienne

# %%
from sklearn.metrics import roc_auc_score
import os

# Charger le modèle temporaire (le nouveau)
nouveau_model_path = "Save/temp_modele.jupiter.keras"
ancien_model_path = "Save/meilleur_modele_jupy.keras"

if os.path.exists(nouveau_model_path):
    nouveau_modele = load_model(nouveau_model_path)
    y_proba_nouveau = nouveau_modele.predict(x_test)
    auc_nouveau = roc_auc_score(y_test, y_proba_nouveau)

    if os.path.exists(ancien_model_path):
        ancien_modele = load_model(ancien_model_path)
        y_proba_ancien = ancien_modele.predict(x_test)
        auc_ancien = roc_auc_score(y_test, y_proba_ancien)

        print(f"\n🎯 Ancien AUC : {auc_ancien:.3f}")
        print(f"🚀 Nouveau AUC : {auc_nouveau:.3f}")

        if auc_nouveau > auc_ancien:
            print("✅ Nouveau modèle meilleur → Remplacement effectué.")
            nouveau_modele.save(ancien_model_path)
            meilleur_modele = nouveau_modele
        else:
            print("❌ Ancien modèle conservé (meilleur AUC).")
            meilleur_modele = ancien_modele
    else:
        print("📁 Aucun modèle précédent. Le modèle actuel devient le meilleur.")
        nouveau_modele.save(ancien_model_path)
        meilleur_modele = nouveau_modele
else:
    raise FileNotFoundError("Aucun modèle temporaire trouvé après l'entraînement.")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 🎯 Ancien AUC : 0.852
# 🚀 Nouveau AUC : 0.500
# ❌ Ancien modèle conservé (meilleur AUC).

# %% [markdown]
# # Prédiction avec le meilleur modèle
# # Probabilités (score entre 0 et 1)

# %%
y_proba = meilleur_modele.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# # On test les seuil pour trouver la meilleur vu que les class partante et restant sont desequilibré

# %%
from sklearn.metrics import f1_score

# Tester plusieurs seuils entre 0.1 et 0.9
# Recherche du meilleur seuil basé sur F1-score
seuils = np.arange(0.1, 0.9, 0.01)
f1_scores = []

# %% [markdown]
# # Une boucle pour verifier tous les seuil vu que le resultat sont desequilibré trop de false par rapport au True donc

# %%
for seuil in seuils:
    y_pred_test = (y_proba > seuil)
    score = f1_score(y_test, y_pred_test)
    f1_scores.append(score)

meilleur_seuil = seuils[np.argmax(f1_scores)]
meilleur_f1 = max(f1_scores)

# %%
print(f"\n💡 Meilleur seuil selon F1-score : {meilleur_seuil:.2f}")
print(f"🔍 F1-score associé : {meilleur_f1:.3f}")
# Out:
# 💡 Meilleur seuil selon F1-score : 0.63
# 🔍 F1-score associé : 0.617

# %%
# Prédictions finales avec le meilleur seuil
y_pred = (y_proba > meilleur_seuil)

# %% [markdown]
# # Matrice de confusion avec meilleur seuil

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédits')
plt.ylabel('Réels')
plt.title('Matrice de confusion')
plt.show()

# %% [markdown]
# # Calculer les métriques de performance

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
error_rate = 1 - accuracy

# %%
print("=== MÉTRIQUES DE PERFORMANCE ===")
print(f"Accuracy (Précision globale): {accuracy:.3f}")
print(f"Précision (pour classe positive): {precision:.3f}")
print(f"Sensibilité/Recall (pour classe positive): {sensitivity:.3f}")
print(f"Spécificité (pour classe négative): {specificity:.3f}")
print(f"Taux d'erreur: {error_rate:.3f}")
# Out:
# === MÉTRIQUES DE PERFORMANCE ===
# Accuracy (Précision globale): 0.840
# Précision (pour classe positive): 0.599
# Sensibilité/Recall (pour classe positive): 0.637
# Spécificité (pour classe négative): 0.892
# Taux d'erreur: 0.160

# %% [markdown]
# # Tracer la courbe F1 en fonction du seuil

# %%
plt.figure()
plt.plot(seuils, f1_scores, label='F1-score')
plt.xlabel("Seuil")
plt.ylabel("F1-score")
plt.title("Optimisation du seuil de classification")
plt.axvline(x=meilleur_seuil, color='r', linestyle='--', label=f'Seuil optimal: {meilleur_seuil:.2f}')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Courbe ROC & AUC

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
auc_score = roc_auc_score(y_test, y_proba)

plt.plot(fpr, tpr, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("Taux de faux positifs (1 - Spécificité)")
plt.ylabel("Taux de vrais positifs (Recall)")
plt.title("Courbe ROC")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # C'est la fin sauf si on voudra ajouté une chose
