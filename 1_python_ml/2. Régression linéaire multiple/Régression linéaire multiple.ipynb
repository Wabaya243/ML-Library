# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#lire la dataset
dataset = pd.read_csv('50_Startups.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
#Modifer les valeurs categoriel en nombre

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
x = np.array(ct.fit_transform(x))
#on supprime la premiere colone pour eviter la colinearité
x = x[:, 1:]
x
# Out:
# array([[0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [0.0, 0.0, 78013.11, 121597.55, 264346.06],
#        [0.0, 1.0, 94657.16, 145077.58, 282574.31],
# ...

# %%
#Diviser en Test Set et Training Set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25 , random_state=0)

# %%
#construction ou entrainer le model

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([104440.72582616, 132253.81567698, 132872.07174272,  71707.78771428,
#        178678.9934985 , 115078.13124331,  66093.9297267 ,  98759.7276409 ,
#        114113.5994088 , 167979.49411476,  95786.77295823,  87785.3497979 ,
#        110455.98228344])

# %%
dfFinal = pd.DataFrame({'Real Values':y_test, 'Predicted Values': y_pred})
dfFinal
# Out:
#     Real Values  Predicted Values
# 0     103282.38     104440.725826
# 1     144259.40     132253.815677
# 2     146121.95     132872.071743
# 3      77798.83      71707.787714
# 4     191050.39     178678.993499
# 5     105008.31     115078.131243
# 6      81229.06      66093.929727
# 7      97483.56      98759.727641
# 8     110352.25     114113.599409
# 9     166187.94     167979.494115
# 10     96778.92      95786.772958
# 11     96479.51      87785.349798
# 12    105733.54     110455.982283

# %%
#on test une valeur au hasard
regressor.predict(np.array([[1, 0, 130000, 140000, 300000]]))
# Out:
# array([158530.49543736])

# %%
# On Verifie la precision 

from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 8591.234654128659
